# %%
import json

# %%
with open('../data/Intra-StateWarData_v4.1.json', 'r') as f:
    war_dict = json.load(f)

# %%
war_dict
# Out:
# [{'WarNum': 500,
#   'WarName': 'First Caucasus',
#   'WarType': 5,
#   'CcodeA': 365.0,
#   'SideA': 'Russia',
#   'CcodeB': -8.0,
#   'SideB': 'Georgians, Dhagestania, Chechens',
#   'Intnl': 0,
#   'StartMonth1': 6,
#   'StartDay1': 10,
#   'StartYear1': 1818,
#   'EndMonth1': -9,
#   'EndDay1': -9,
#   'EndYear1': 1822.0,
#   'StartMonth2': -8,
#   'StartDay2': -8,
#   'StartYear2': -8,
#   'EndMonth2': -8,
#   'EndDay2': -8,
#   'EndYear2': -8,
#   'TransFrom': -8.0,
#   'WhereFought': 2,
#   'Initiator': 'Chechens',
#   'Outcome': 1,
#   'TransTo': -8,
#   'SideADeaths': '5000',
#   'SideBDeaths': '6000',
#   'Version': 4.1},
#  {'WarNum': 501,
#   'WarName': 'Sidon-Damascus',
#   'WarType': 6,
#   'CcodeA': -8.0,
#   'SideA': 'Sidon',
#   'CcodeB': -8.0,
#   'SideB': 'Damascus & Aleppo',
#   'Intnl': 0,
#   'StartMonth1': 6,
#   'StartDay1': -9,
#   'StartYear1': 1820,
#   'EndMonth1': 7,
#   'EndDay1': 21,
#   'EndYear1': 1821.0,
#   'StartMonth2': -8,
#   'StartDay2': -8,
# ...
