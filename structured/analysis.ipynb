# %%
import pandas as pd

# %%
war_df = pd.read_csv('../data/Intra-StateWarData_v4.1.csv', encoding='ISO-8859-1')

# %%
war_df
# Out:
#      WarNum                 WarName  WarType  CcodeA         SideA  CcodeB  \
# 0       500          First Caucasus        5   365.0        Russia    -8.0
# 1       501          Sidon-Damascus        6    -8.0         Sidon    -8.0
# 2       502      First Two Sicilies        4   300.0       Austria    -8.0
# 3       502      First Two Sicilies        4   329.0  Two Sicilies    -8.0
# 4       503       Spanish Royalists        4   230.0         Spain    -8.0
# ..      ...                     ...      ...     ...           ...     ...
# 437     938           Third Somalia        4   520.0       Somalia    -8.0
# 438     938           Third Somalia        4   530.0      Ethiopia    -8.0
# 439     938           Third Somalia        4    -8.0            -8   531.0
# 440     940  Second Sri Lanka Tamil        5   780.0     Sri Lanka    -8.0
# 441     941    Second Yemeni Cleric        4   679.0         Yemen    -8.0
#
# ...
